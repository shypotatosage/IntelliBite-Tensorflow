# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
# Out:
# WARNING:tensorflow:From C:\Users\miche\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img_height, img_width = 128, 128
batch_size = 20

train_ds = tf.keras.utils.image_dataset_from_directory(
    "data/train",
    labels = 'inferred',
    label_mode= 'categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(224,224),
    shuffle= True,
    seed=None,
    validation_split=None,
    subset= None,
    interpolation = "bilinear",
    follow_links= False,
    
    crop_to_aspect_ratio = False
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "data/validation",
    labels = 'inferred',
    label_mode= 'categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(224,224),
    shuffle= True,
    seed=None,
    validation_split=None,
    subset= None,
    interpolation = "bilinear",
    follow_links= False,
    crop_to_aspect_ratio = False
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "data/test",
    labels = 'inferred',
    label_mode= 'categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(224,224),
    shuffle= True,
    seed=None,
    validation_split=None,
    subset= None,
    interpolation = "bilinear",
    follow_links= False,
    crop_to_aspect_ratio = False
)
# Out:
# Found 3744 files belonging to 38 classes.
# Found 371 files belonging to 38 classes.
# Found 379 files belonging to 38 classes.

# %%
resnet_model = tf.keras.Sequential()

pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(224,224,3),
                   pooling='avg',classes=5,
                   weights='imagenet')
for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(tf.keras.layers.Flatten())
resnet_model.add(tf.keras.layers.Dense(512, activation='relu'))
resnet_model.add(tf.keras.layers.Dense(38, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\miche\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\miche\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
resnet_model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\miche\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq=38*32)

# %%
resnet_model.load_weights('saved_weights/')

# %%
resnet_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 10,
    callbacks=[cp_callback]
)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\miche\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\miche\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 117/117 [==============================] - 150s 1s/step - loss: 1.2654 - accuracy: 0.6888 - val_loss: 0.2782 - val_accuracy: 0.9137
# Epoch 2/10
# 117/117 [==============================] - 155s 1s/step - loss: 0.2658 - accuracy: 0.9204 - val_loss: 0.1462 - val_accuracy: 0.9515
# Epoch 3/10
# 117/117 [==============================] - 203s 2s/step - loss: 0.1175 - accuracy: 0.9688 - val_loss: 0.1014 - val_accuracy: 0.9704
# Epoch 4/10
# 117/117 [==============================] - 211s 2s/step - loss: 0.0706 - accuracy: 0.9832 - val_loss: 0.1081 - val_accuracy: 0.9704
# Epoch 5/10
# 117/117 [==============================] - 201s 2s/step - loss: 0.0430 - accuracy: 0.9896 - val_loss: 0.0782 - val_accuracy: 0.9757
# Epoch 6/10
# 117/117 [==============================] - 202s 2s/step - loss: 0.0347 - accuracy: 0.9923 - val_loss: 0.1400 - val_accuracy: 0.9515
# Epoch 7/10
# 117/117 [==============================] - 201s 2s/step - loss: 0.0291 - accuracy: 0.9925 - val_loss: 0.1488 - val_accuracy: 0.9569
# Epoch 8/10
# 117/117 [==============================] - 202s 2s/step - loss: 0.0332 - accuracy: 0.9928 - val_loss: 0.0918 - val_accuracy: 0.9704
# Epoch 9/10
# 117/117 [==============================] - 206s 2s/step - loss: 0.0219 - accuracy: 0.9957 - val_loss: 0.1540 - val_accuracy: 0.9569
# Epoch 10/10
# 117/117 [==============================] - 198s 2s/step - loss: 0.0249 - accuracy: 0.9920 - val_loss: 0.1297 - val_accuracy: 0.9677

# %%
resnet_model.save_weights('saved_weights/')

# %%
test_loss,test_accuracy = resnet_model.evaluate(test_ds)
# Out:
# 12/12 [==============================] - 21s 2s/step - loss: 0.1245 - accuracy: 0.9683

# %%
import itertools
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

true_labels = []
predicted_labels = []

# Iterate through the validation set and make predictions
for images, labels in val_ds:
    true_labels.extend(np.argmax(labels, axis=1))  # Get true labels
    predictions = resnet_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))  # Get predicted labels

# Create a classification report
class_names = val_ds.class_names
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Print the classification report
print("Classification Report:\n", report)

# Create a confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix
def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(16, 12))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)
    
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
plot_confusion_matrix(confusion, class_names)
plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 3s 3s/step
# Classification Report:
#                 precision    recall  f1-score   support
#
#         apple       1.00      0.90      0.95        10
#        banana       0.88      0.78      0.82         9
#      beetroot       1.00      1.00      1.00        10
#   bell pepper       0.82      1.00      0.90         9
#       cabbage       1.00      1.00      1.00        10
#      capsicum       1.00      0.80      0.89        10
#        carrot       1.00      0.89      0.94         9
#   cauliflower       1.00      1.00      1.00        10
# chilli pepper       1.00      0.89      0.94         9
#          corn       1.00      1.00      1.00        10
#      cucumber       1.00      1.00      1.00        10
#      eggplant       1.00      1.00      1.00        10
#        garlic       1.00      1.00      1.00        10
#        ginger       1.00      1.00      1.00        10
#        grapes       1.00      1.00      1.00         9
#      jalepeno       0.82      1.00      0.90         9
#          kiwi       1.00      1.00      1.00        10
#         lemon       1.00      1.00      1.00        10
#       lettuce       1.00      1.00      1.00         9
#         mango       1.00      1.00      1.00        10
#         onion       1.00      1.00      1.00        10
#        orange       0.82      1.00      0.90         9
#       paprika       1.00      1.00      1.00        10
#          pear       1.00      1.00      1.00        10
#          peas       1.00      1.00      1.00        10
#     pineapple       1.00      1.00      1.00        10
#   pomegranate       1.00      1.00      1.00        10
#        potato       0.75      0.90      0.82        10
#       raddish       0.90      1.00      0.95         9
#          rice       0.91      1.00      0.95        10
#         salad       1.00      0.90      0.95        10
#      sandwich       1.00      1.00      1.00        10
#     soy beans       1.00      1.00      1.00        10
#       spinach       1.00      1.00      1.00        10
#   sweetpotato       1.00      0.70      0.82        10
#        tomato       1.00      1.00      1.00        10
#        turnip       1.00      1.00      1.00        10
#    watermelon       1.00      1.00      1.00        10
#
#      accuracy                           0.97       371
#     macro avg       0.97      0.97      0.97       371
#  weighted avg       0.97      0.97      0.97       371

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(resnet_model)
tflite_model = converter.convert()

with open("model.tflite", 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\miche\AppData\Local\Temp\tmpdhrbzm9m\assets
# INFO:tensorflow:Assets written to: C:\Users\miche\AppData\Local\Temp\tmpdhrbzm9m\assets

# %%
for i in class_names:
    print('"' + i.title() + '", ', end="")
# Out:
# "Apple", "Banana", "Beetroot", "Bell Pepper", "Cabbage", "Capsicum", "Carrot", "Cauliflower", "Chilli Pepper", "Corn", "Cucumber", "Eggplant", "Garlic", "Ginger", "Grapes", "Jalepeno", "Kiwi", "Lemon", "Lettuce", "Mango", "Onion", "Orange", "Paprika", "Pear", "Peas", "Pineapple", "Pomegranate", "Potato", "Raddish", "Rice", "Salad", "Sandwich", "Soy Beans", "Spinach", "Sweetpotato", "Tomato", "Turnip", "Watermelon", 38

# %%
import numpy as np

sunflower_url = "https://befreshcorp.net/wp-content/uploads/2017/07/product-packshot-Orange.jpg"
sunflower_path = tf.keras.utils.get_file('orange', origin=sunflower_url)

img = tf.keras.utils.load_img(
    "pomegranate.jpg", target_size=(224, 224)
)
img_array = tf.keras.utils.img_to_array(img)
plt.imshow(img_array/255)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = resnet_model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(val_ds.class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 125ms/step
# This image most likely belongs to pomegranate with a 5.59 percent confidence.

# %%
img = tf.keras.utils.load_img(
    "orange.jpg", target_size=(224, 224, 3)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = resnet_model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(val_ds.class_names[np.argmax(score)], 100 * np.max(score))
)

print(score)
# Out:
# 1/1 [==============================] - 0s 102ms/step
# This image most likely belongs to orange with a 6.79 percent confidence.
# tf.Tensor(
# [0.02518637 0.02518637 0.02518637 0.02518637 0.02518637 0.02518637
#  0.02518637 0.02518637 0.02518637 0.02518637 0.02518638 0.02518637
#  0.02518637 0.02518637 0.02518637 0.02518637 0.02537523 0.02520372
#  0.02518637 0.0251865  0.0251864  0.06789267 0.02518717 0.02518639
#  0.02518639 0.02518638 0.02518637 0.02518761 0.02518637 0.02518637
#  0.02518637 0.02518637 0.02518942 0.02518637 0.02518637 0.02518641
#  0.02518637 0.02518643], shape=(38,), dtype=float32)
